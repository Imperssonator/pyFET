# %%
import pandas as pd

# %%
df=pd.read_csv('~/Google Drive/Papers/Tie Chain Model/Data/5 um/Global/res_5_global.csv')
df5_adap=pd.read_csv('~/Google Drive/Papers/Tie Chain Model/Data/5 um/Adaptive/res_5_adaptive.csv')
df10_glob=pd.read_csv('~/Google Drive/Papers/Tie Chain Model/Data/10 um/Global/res_10_global.csv')

# %%
df=df.append(df5_adap)
df=df.append(df10_glob)
df=df.reset_index()

# %%
df.columns = ['index','ImName','Sfull','CorrLen','AvgOrient',
              'FLD','MeanLen','MeanWid','Mn','PDI','TCD',
              'TCDstd','NumSims','NumFibs','NumChains']

# %%
df.iloc[range(0,df.shape[0],9)]
# Out:
#      index                                ImName     Sfull    CorrLen  \
# 0        0                               0_2.jpg  0.415990   533.0754
# 9        9                               0_4.jpg  0.650520   409.7112
# 18      18                               0_6.jpg  0.648140   371.8295
# 27      27                              20_2.jpg  0.686560   534.5996
# 36      36                              20_4.jpg  0.826640   251.0066
# 45      45                              20_6.jpg  0.844810   420.5600
# 54      54                  BP5-lowerchannel.jpg  0.589780   503.8116
# 63      63                           BV5-001.jpg  0.885430   492.6874
# 72       0                             100_2.jpg  0.911600   453.6728
# 81       9                18hrSpin1.004.flat.jpg  0.520850   658.2689
# 90      18                48hrSpin1.006.flat.jpg  0.344630  1083.6136
# 99      27                48hrSpin3.005.flat.jpg  0.554290   718.4728
# ...

# %%
import bokeh
from bokeh.plotting import figure, show, output_notebook, output_file
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="00dc6125-1f85-4736-8626-d9a2946f62a5">Loading BokehJS ...</span>
#     </div>

# %%
def plot_v_tcd(df,col,color_col='Author'):
#     colors = {}
#     for c in df[color_col].unique():
#         colors[c] = np.random.randint( 0,256, (1,3))
#         df.loc[df[color_col]==c,'color'] = '#' + ''.join([ '%02x'%s for s in colors[c][0]] )
    df = df.loc[~df[col].isnull()]
    cds = bokeh.models.ColumnDataSource(df)
    plot = figure(width=500, height=500)
    plot.circle(source=cds,
                x=col,
                y='TCD',
#                 fill_color=df['color'][~df[col].apply(lambda x: np.isnan(x))],
                size=10, 
                fill_alpha=0.6)
    plot.xaxis.axis_label = col
    plot.yaxis.axis_label = 'Tie Chain Density (1/nm)'
    plot.add_tools(
        bokeh.models.HoverTool(
            tooltips=[
                ('Image','@ImName'),
                ('Sfull','@Sfull'),
                ('FLD','@FLD'),
                ('Decay Length','@CorrLen')
            ]
        )
    )

    show(plot)

# %%
df.to_csv(path_or_buf='/Users/Imperssonator/Google Drive/Papers/Tie Chain Model/Data/res_all.csv')

# %%
df40=df.iloc[range(8,df.shape[0],9)]['TCD']
df40.reset_index()['TCD']
# Out:
# 0     0.209610
# 1     0.231850
# 2     0.210260
# 3     0.339270
# 4     0.653480
# 5     0.835320
# 6     0.807520
# 7     0.596860
# 8     1.209400
# 9     1.146400
# 10    0.660120
# 11    0.820520
# 12    1.180200
# 13    1.084500
# 14    0.596380
# 15    0.731870
# 16    1.260600
# 17    1.150700
# 18    1.233400
# 19    1.013500
# 20    1.531300
# 21    0.912040
# 22    1.140900
# 23    0.567440
# 24    0.499020
# 25    0.070330
# 26    0.068389
# 27    0.075217
# 28    0.125620
# 29    0.147450
# 30    0.123670
# 31    0.138120
# 32    0.135990
# 33    0.467520
# 34    0.166250
# 35    0.172940
# 36    0.148170
# 37    0.158420
# Name: TCD, dtype: float64

# %%
df_225 = pd.DataFrame()
df_225['FLD']=(df.iloc[range(2,df.shape[0],9)]['FLD']).reset_index()['FLD']
df_225['Sfull']=(df.iloc[range(2,df.shape[0],9)]['Sfull']).reset_index()['Sfull']
df_225['decayLen']=(df.iloc[range(2,df.shape[0],9)]['CorrLen']).reset_index()['CorrLen']
df_225['10kD']=(df.iloc[range(2,df.shape[0],9)]['TCD']).reset_index()['TCD']
df_225['25kD']=(df.iloc[range(5,df.shape[0],9)]['TCD']).reset_index()['TCD']
df_225['40kD']=(df.iloc[range(8,df.shape[0],9)]['TCD']).reset_index()['TCD']
df_225.to_csv(path_or_buf='/Users/Imperssonator/Google Drive/Papers/Tie Chain Model/Data/res_225.csv')

# %%
df_125 = pd.DataFrame()
df_125['FLD']=(df.iloc[range(0,df.shape[0],9)]['FLD']).reset_index()['FLD']
df_125['Sfull']=(df.iloc[range(0,df.shape[0],9)]['Sfull']).reset_index()['Sfull']
df_125['decayLen']=(df.iloc[range(0,df.shape[0],9)]['CorrLen']).reset_index()['CorrLen']
df_125['10kD']=(df.iloc[range(0,df.shape[0],9)]['TCD']).reset_index()['TCD']
df_125['25kD']=(df.iloc[range(3,df.shape[0],9)]['TCD']).reset_index()['TCD']
df_125['40kD']=(df.iloc[range(6,df.shape[0],9)]['TCD']).reset_index()['TCD']
df_125.to_csv(path_or_buf='/Users/Imperssonator/Google Drive/Papers/Tie Chain Model/Data/res_125.csv')

# %%
df.iloc[range(2,df.shape[0],9)].to_csv(path_or_buf='/Users/Imperssonator/Google Drive/Papers/Tie Chain Model/Data/res_225.csv')

# %%
cds1 = bokeh.models.ColumnDataSource(df.iloc[range(2,df.shape[0],9)])
plot = figure(width=700, height=600, active_scroll='wheel_zoom')
plot.circle(source=cds1,
            x='FLD',
            y='TCD',
            fill_color='red',
            size=10, 
            fill_alpha=0.6)
plot.xaxis.axis_label = 'Fiber Length Density (1/um)'
plot.yaxis.axis_label = 'Tie Chain Density (1/nm)'
plot.add_tools(
    bokeh.models.HoverTool(
        tooltips=[
            ('Image','@ImName'),
            ('Sfull','@Sfull'),
            ('FLD','@FLD'),
            ('Decay Length','@CorrLen'),
            ('Mean Width','@MeanWid')
        ]
    )
)

cds2 = bokeh.models.ColumnDataSource(df.iloc[range(5,df.shape[0],9)])
plot.circle(source=cds2,
            x='FLD',
            y='TCD',
            fill_color='green',
            size=10, 
            fill_alpha=0.6)
plot.add_tools(
    bokeh.models.HoverTool(
        tooltips=[
            ('Image','@ImName'),
            ('Sfull','@Sfull'),
            ('FLD','@FLD'),
            ('Decay Length','@CorrLen'),
            ('Mean Width','@MeanWid')
        ]
    )
)

cds3 = bokeh.models.ColumnDataSource(df.iloc[range(8,df.shape[0],9)])
plot.circle(source=cds3,
            x='FLD',
            y='TCD',
            fill_color='navy',
            size=10, 
            fill_alpha=0.6)
plot.add_tools(
    bokeh.models.HoverTool(
        tooltips=[
            ('Image','@ImName'),
            ('Sfull','@Sfull'),
            ('FLD','@FLD'),
            ('Decay Length','@CorrLen'),
            ('Mean Width','@MeanWid')
        ]
    )
)

plot.xaxis.major_label_text_font_size='16pt'
plot.yaxis.major_label_text_font_size='16pt'
plot.toolbar_location = None
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9d3d52da-032c-4ee4-ac77-78fca5a8d20e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
plot.toolbar.active_scroll
# Out:
# 'auto'

# %%
cds1 = bokeh.models.ColumnDataSource(df.iloc[range(0,df.shape[0],9)])
plot = figure(width=700, height=600, active_scroll='wheel_zoom')
plot.circle(source=cds1,
            x='FLD',
            y='TCD',
            fill_color='red',
            size=10, 
            fill_alpha=0.6)
plot.xaxis.axis_label = 'Fiber Length Density (1/um)'
plot.yaxis.axis_label = 'Tie Chain Density (1/nm)'
plot.add_tools(
    bokeh.models.HoverTool(
        tooltips=[
            ('Image','@ImName'),
            ('Sfull','@Sfull'),
            ('FLD','@FLD'),
            ('Decay Length','@CorrLen'),
            ('Mean Width','@MeanWid')
        ]
    )
)

cds2 = bokeh.models.ColumnDataSource(df.iloc[range(3,df.shape[0],9)])
plot.circle(source=cds2,
            x='FLD',
            y='TCD',
            fill_color='green',
            size=10, 
            fill_alpha=0.6)
plot.add_tools(
    bokeh.models.HoverTool(
        tooltips=[
            ('Image','@ImName'),
            ('Sfull','@Sfull'),
            ('FLD','@FLD'),
            ('Decay Length','@CorrLen'),
            ('Mean Width','@MeanWid')
        ]
    )
)

cds3 = bokeh.models.ColumnDataSource(df.iloc[range(6,df.shape[0],9)])
plot.circle(source=cds3,
            x='FLD',
            y='TCD',
            fill_color='navy',
            size=10, 
            fill_alpha=0.6)
plot.add_tools(
    bokeh.models.HoverTool(
        tooltips=[
            ('Image','@ImName'),
            ('Sfull','@Sfull'),
            ('FLD','@FLD'),
            ('Decay Length','@CorrLen'),
            ('Mean Width','@MeanWid')
        ]
    )
)

plot.xaxis.major_label_text_font_size='16pt'
plot.yaxis.major_label_text_font_size='16pt'
plot.toolbar_location = None
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="517b06b3-e6a6-442d-9293-07707db72921"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...

# %%
cds1 = bokeh.models.ColumnDataSource(df.iloc[range(1,df.shape[0],9)])
plot = figure(width=700, height=600, active_scroll='wheel_zoom')
plot.circle(source=cds1,
            x='FLD',
            y='TCD',
            fill_color='red',
            size=10, 
            fill_alpha=0.6)
plot.xaxis.axis_label = 'Fiber Length Density (1/um)'
plot.yaxis.axis_label = 'Tie Chain Density (1/nm)'
plot.add_tools(
    bokeh.models.HoverTool(
        tooltips=[
            ('Image','@ImName'),
            ('Sfull','@Sfull'),
            ('FLD','@FLD'),
            ('Decay Length','@CorrLen'),
            ('Mean Width','@MeanWid')
        ]
    )
)

cds2 = bokeh.models.ColumnDataSource(df.iloc[range(4,df.shape[0],9)])
plot.circle(source=cds2,
            x='FLD',
            y='TCD',
            fill_color='green',
            size=10, 
            fill_alpha=0.6)
plot.add_tools(
    bokeh.models.HoverTool(
        tooltips=[
            ('Image','@ImName'),
            ('Sfull','@Sfull'),
            ('FLD','@FLD'),
            ('Decay Length','@CorrLen'),
            ('Mean Width','@MeanWid')
        ]
    )
)

cds3 = bokeh.models.ColumnDataSource(df.iloc[range(7,df.shape[0],9)])
plot.circle(source=cds3,
            x='FLD',
            y='TCD',
            fill_color='navy',
            size=10, 
            fill_alpha=0.6)
plot.add_tools(
    bokeh.models.HoverTool(
        tooltips=[
            ('Image','@ImName'),
            ('Sfull','@Sfull'),
            ('FLD','@FLD'),
            ('Decay Length','@CorrLen'),
            ('Mean Width','@MeanWid')
        ]
    )
)

plot.xaxis.major_label_text_font_size='16pt'
plot.yaxis.major_label_text_font_size='16pt'
plot.toolbar_location = None
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="984e797b-f287-454c-9aa0-afd49b7b909b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
# ...
